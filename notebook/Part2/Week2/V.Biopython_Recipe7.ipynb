# %% [markdown]
# # V. Biopython

# %% [markdown]
# ## Introduction : Using Big Programming Library

# %% [markdown]
# 바이오파이썬은,
# 1. computational molecular biology를 위한 module들의 집합
# 2. bioinformatics project에서 필요한 basic task들을 수행할 수 있음
#  - parsing file format(gene sequence, protein sequence 등..)
#  - downloading files from repositories (NCBI 등)
#  - running bioinformatics 알고리즘 (BLAST 등)
#  - clustering, machine learning, data analysis, data visualization 의 알고리즘을 실행

# %% [markdown]
# ## Installing Biopython

# %% [markdown]
# 바이오파이썬 설치 : http://biopython.org/wiki/Download

# %% [markdown]
# 넘피 package 설치 : http://numpy.scipy.org

# %% [markdown]
# ## Let's Get Started

# %%
import sys

# %%
sys.path.append("user/junseok/appdata/local/enthought/canopy/user/lib/site-packages/") # 바이오파이썬 모듈이 설치된 장소를 설정??

# %%
import Bio

# %%
dir(Bio)
# Out:
# ['BiopythonDeprecationWarning',
#  'BiopythonExperimentalWarning',
#  'BiopythonParserWarning',
#  'BiopythonWarning',
#  'MissingExternalDependencyError',
#  'MissingPythonDependencyError',
#  '__builtins__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__version__']

# %%
Bio.__version__
# Out:
# '1.64'

# %%
help(Bio)
# Out:
# Help on package Bio:
#
# NAME
#     Bio - Collection of modules for dealing with biological data in Python.
#
# FILE
#     c:\users\junseok\appdata\local\enthought\canopy\user\lib\site-packages\bio\__init__.py
#
# DESCRIPTION
#     The Biopython Project is an international association of developers
#     of freely available Python tools for computational molecular biology.
#
#     http://biopython.org
#
# PACKAGE CONTENTS
#     Affy (package)
#     Align (package)
#     AlignIO (package)
#     Alphabet (package)
#     Application (package)
#     Blast (package)
#     CAPS (package)
#     Cluster (package)
#     CodonAlign (package)
#     Compass (package)
#     Crystal (package)
#     Data (package)
#     DocSQL
#     Emboss (package)
#     Entrez (package)
#     ExPASy (package)
#     FSSP (package)
#     File
#     GA (package)
#     GenBank (package)
#     Geo (package)
#     Graphics (package)
#     HMM (package)
#     Index
#     KDTree (package)
#     KEGG (package)
# ...

# %% [markdown]
# All other modules will be imported from Bio as follows:

# %%
from Bio import Seq

# %%
from Bio.Alphabet import IUPAC

# %%
from Bio.Data import CodonTable
