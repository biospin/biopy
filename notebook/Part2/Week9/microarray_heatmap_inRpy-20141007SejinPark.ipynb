# %%
Biopython Study

# %% [raw]
# https://www.facebook.com/biospintalk
# 바이오스핀 - 바이오 파이썬 스터디
# 발표일자 : 2014.10.7
# 발표자 : 박세진

# %% [markdown]
# 출처 : http://www2.warwick.ac.uk/fac/sci/moac/people/students/peter_cock/r/heatmap/

# %%
# %load_ext rpy2.ipython

# %%
source("http://www.bioconductor.org/biocLite.R")
biocLite("ALL")

# %%
# %%R
# library("ALL")
# Out:
# Loading required package: Biobase
# Loading required package: BiocGenerics
# Loading required package: parallel
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
# The following object is masked from ‘package:stats’:
#
#     xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, as.vector, cbind, colnames,
#     do.call, duplicated, eval, evalq, Filter, Find, get, intersect,
#     is.unsorted, lapply, Map, mapply, match, mget, order, paste, pmax,
#     pmax.int, pmin, pmin.int, Position, rank, rbind, Reduce, rep.int,
#     rownames, sapply, setdiff, sort, table, tapply, union, unique,
#     unlist
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
# ...

# %%
# %R data("ALL")
# Out:
# <StrVector - Python:0x5fcdfc8 / R:0x6f567c8>
# [str]

# %%
# %R ALL$mol.biol
# Out:
# <FactorVector - Python:0x5fda098 / R:0x614a420>
# [       2,        4,        2, ...,        4,        4,        4]

# %%
# %R eset <- ALL[, ALL$mol.biol %in% c("BCR/ABL", "ALL1/AF4")]
# Out:
# <RS4 - Python:0x5fcdef0 / R:0x742f528>

# %%
# %R heatmap(exprs(eset[1:100,]))
# Out:
# <ListVector - Python:0x5fda3f8 / R:0x74ed2f8>
# [IntVector, IntVector, RNULLType, RNULLType]
#   rowInd: <class 'rpy2.robjects.vectors.IntVector'>
#   <IntVector - Python:0x5fda440 / R:0x61205d0>
# [      56,       18,       97, ...,       17,       26,       52]
#   colInd: <class 'rpy2.robjects.vectors.IntVector'>
#   <IntVector - Python:0x5fda128 / R:0x61a9db0>
# [      47,       45,       44, ...,       23,       39,        8]
#   Rowv: <type 'rpy2.rinterface.RNULLType'>
#   rpy2.rinterface.NULL
#   Colv: <type 'rpy2.rinterface.RNULLType'>
#   rpy2.rinterface.NULL

# %%
# %%R
# library(limma)
# f <- factor(as.character(eset$mol.biol))
# design <- model.matrix(~f)
# fit <- eBayes(lmFit(eset,design))
# Out:
# Attaching package: ‘limma’
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     plotMA

# %%
# %R topTable(fit, coef=2)
# Out:
#       logFC   AveExpr          t       P.Value     adj.P.Val          B
# 0 -3.076231  4.611284 -27.498596  4.663431e-31  5.887581e-27  56.326530
# 1 -3.971906  4.864721 -19.754784  1.033405e-24  5.896502e-21  44.238316
# 2 -3.391662  4.284529 -19.614970  1.401149e-24  5.896502e-21  43.972977
# 3 -3.086992  3.474092 -17.007390  5.695120e-22  1.797522e-18  38.646150
# 4  3.618194  8.438482  15.456552  2.809128e-20  7.093049e-17  35.106922
# 5 -2.500488  3.733012 -14.839236  1.428253e-19  3.005283e-16  33.613911
# 6 -2.269730  5.191015 -12.963979  2.638314e-17  4.758388e-14  28.764708
# 7 -1.036051  6.937965 -10.487769  5.126800e-14  8.090730e-11  21.602163
# 8  1.844998  7.826900  10.382137  7.206177e-14  1.010866e-10  21.277315
# 9  1.583904  4.638885  10.257306  1.079482e-13  1.362846e-10  20.891453

# %%
# %%R
# selected  <- p.adjust(fit$p.value[, 2]) <0.05
# esetSel <- eset [selected, ]

# %%
# %%R
# heatmap(exprs(esetSel))

# %%
# %R heatmap(exprs(esetSel), col=topo.colors(100))
# Out:
# <ListVector - Python:0x70e77a0 / R:0x6124058>
# [IntVector, IntVector, RNULLType, RNULLType]
#   rowInd: <class 'rpy2.robjects.vectors.IntVector'>
#   <IntVector - Python:0x70e7a70 / R:0x7de65d0>
# [      83,      146,       92, ...,      130,        6,      126]
#   colInd: <class 'rpy2.robjects.vectors.IntVector'>
#   <IntVector - Python:0x70e73b0 / R:0x5f9f4c0>
# [      27,        3,       44, ...,        4,        9,        1]
#   Rowv: <type 'rpy2.rinterface.RNULLType'>
#   rpy2.rinterface.NULL
#   Colv: <type 'rpy2.rinterface.RNULLType'>
#   rpy2.rinterface.NULL

# %%
# %%R
# color.map <- function(mol.biol) { if (mol.biol=="ALL1/AF4") "#FF0000" else "#0000FF" }
# patientcolors <- unlist(lapply(esetSel$mol.bio, color.map))
# heatmap(exprs(esetSel), col=topo.colors(100), ColSideColors=patientcolors)

# %%
# %%R
# library(gplots)
# heatmap.2(exprs(esetSel), col=redgreen(75), scale="row", ColSideColors=patientcolors,
#            key=TRUE, symkey=FALSE, density.info="none", trace="none", cexRow=0.5)
# Out:
# Attaching package: ‘gplots’
#
# The following object is masked from ‘package:stats’:
#
#     lowess
